# %% [markdown]
# First jupyter

# %%
import pandas as pd
# %matplotlib inline

# %%
import numpy as np

# %%
_ta = np.tile(np.arange(5),(10,1))
_col = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')[:5]
df = pd.DataFrame(_ta, columns=_col)

_index = ['row1', 'row2', 'row3', 'row4', 'row5', 'row6', 'row7', 'row8']
_columns = ['category1', 'category2', 'category3', 'category4', 'category5']
df_orig = pd.DataFrame(
        data = np.random.random((len(_index),len(_columns))), 
        columns=_columns,
        index = _index)

# %%
df_orig.plot()
